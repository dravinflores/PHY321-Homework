# %% [markdown]
# # Homework 3
# Dravin Flores
#
# ---

# %% [markdown]
# ### Exercise 1
# First, we need to list the information we're given:
# * $\mathbf{v}_0 = \left(100, 0, 0\right)$
# * $\mathbf{a}(t) = \left(0, -20 - 10t, 0\right)$
#
# Next, we suppose that our reference frame is such that:
# * We're dealing with a Cartesian Coordinate System
# * $t_0 = 0$
#
# ---
#
# 1A. Velocity Function
#
# ---
# $$
#     \mathbf{v}(t) - \mathbf{v}(t_0) = \int_{t_0}^{t} \mathbf{a}(t) dt \qquad \Rightarrow \qquad \mathbf{v}(t) = \mathbf{v}_0 + \int_{t_0}^{t} \mathbf{a}(t) dt
# $$
#
# $$
#     \mathbf{v}(t) = (100, 0, 0) + (0, -20t - 5t^2 + 20t_0 + 5t_0^2, 0) = \left[100, -20t - 5t^2, 0\right]
# $$
#
# ---
#
# 1B. Position Function
#
# ---
# $$
#     \mathbf{r}(t) = \mathbf{r_0} + \int_{t_0}^{t} \mathbf{v}(t) dt = \mathbf{r_0} \left[100t - 100t_0, \left(-10t^2 - \frac{5}{3}t^3\right) - \left(-10t_0^2 - \frac{5}{3}t_0^3 \right), 0\right] = \mathbf{r_0} + \left[ 100t, -10t^2 - \frac{5}{3}t^3, 0 \right]
# $$
#
# ---
#
# 1C.
#
# ---
# * $L = 2\text{m}$
# * We can assume that $\mathbf{r_0} = \left[0, 0, 0\right]$
# $$
#     r_x = 2 \qquad \Rightarrow \qquad 100t = 2, \quad t = \frac{1}{50} \text{s}
# $$
#
# ---
#
# 1D.
#
# ---
# * $t = \frac{1}{50} \text{s}$
# $$
#     r_y(t) = -10\left(\frac{1}{50}\right)^2 - \frac{5}{3}\left(\frac{1}{50}\right)^3 = \frac{-301}{75000} \text{m}
# $$
#
# ---
#
# 1E.
#
# ---
# * $ \mathbf{r}_f = \left(0, \frac{-301}{75000}\right) $
# * Angle from horizontal indiates that we're looking for the angle from $ \mathbf{\hat{\imath}} = (1, 0)$
# $$
#     \mathbf{r}_f \cdot \mathbf{\hat{\imath}} = \|\mathbf{r}_f\| \cdot \|\mathbf{\hat{\imath}}\|\cos{\theta} \qquad \Rightarrow \qquad \theta = \cos^{-1}{\left(0\right)} = 0^\circ
# $$

# %% [markdown]
# ### Exercise 2
# * Taylor exercise 2.3
# * $f_{\text{lin}} = 3 \pi \eta D v$
# * $f_{\text{quad}} = \kappa \rho A v^2$
# * $R = \frac{D v \rho}{\eta}$
# * $\kappa = \frac{1}{4}$
#
# ---
#
# 2A.
#
# ---
# $$
#     \tag{1} \frac{f_{\text{quad}}}{f_{\text{lin}}} = \frac{\kappa \rho A v}{3 \pi \eta D} = \frac{\rho A v}{12 \pi \eta D}
# $$
#
# $$
#     \tag{2} A = \pi R^2 = \pi \left(\frac{D}{2}\right)^2
# $$
#
# $$
#     \tag{3} \frac{f_{\text{quad}}}{f_{\text{lin}}} = \frac{\frac{1}{4}\rho D^2 v}{12 \pi \eta D} = \frac{\rho D v}{48 \pi \eta} = \frac{R}{48}
# $$
#
# ---
#
# 2B.
#
# ---
# * $D = 2 \text{mm}$
# * $v = 5 \text{cm/s}$
# * $\eta = 1.3 \frac{\text{g}}{\text{cm}^3}$
# * $\rho = 12 \text{N} \cdot \text{s/}\text{m}^2$
# $$
#     \frac{R}{48} = \frac{\rho D v}{48 \pi \eta} = \frac{\left(12 \text{N} \cdot \text{s/}\text{m}^2\right) \left(2 \cdot 10^{-3} \text{m}\right) \left(5 \cdot 10^{-2} \text{cm/s}\right)}{48 \pi \left(1.3 \frac{\text{g}}{\text{cm}^3} \cdot \left(\frac{100 \text{cm}}{1 \text{m}}\right)^3\right)} \approx 6.12 \cdot 10^{-12}
# $$

# %% [markdown]
# ### Exercise 3
#
# ---
#
# 3A.
#
# ---
#
# $$
#     \tag{1}
#     v_{y}(t) = v_{term} \left(1 - e^{\frac{-t}{\tau}}\right) = \frac{mg}{b}\left(1 - e^{\frac{-t}{\tau}}\right)
# $$
#
# $$
#     \tag{2}
#     = \frac{mg}{b} \left(1 - \left(1 - \frac{t}{\tau} + \frac{1}{2} \frac{t^2}{\tau^2} + \cdots \right)\right)
# $$
#
# $$
#     \tag{3}
#     = \left(\frac{mg}{b} \frac{t}{\tau} - \frac{mg}{b} \frac{1}{2} \frac{t^2}{\tau^2} + \cdots \right)
# $$
#
# If we suppose that $v(t) << v_{term}$, this means that $t << t_{term}$. If we say that $\tau = \frac{m}{b}$, we have:
# $$
#     \tag{4}
#     v_{y}(t) \approx \left(\frac{mg}{b} \frac{b}{m} t + \cdots \right) \approx gt
# $$
#
# As we use the first term of the Taylor Expansion, as we have assumed the other terms will quickly reach $0$ as $t^n \to 0$
#
# ---
#
# 3B.
#
# ---
#
# Given that $v_{yo} = 0$, we have:
# $$
#     \tag{1}
#     y(t) = v_{term} t + \left(v_{yo} - v_{term}\right) \tau \left(1 - e^{\frac{-t}{\tau}}\right) = v_{term} t + \left(- v_{term}\right) \tau \left(1 - e^{\frac{-t}{\tau}}\right)
# $$
#
# $$
#     \tag{2}
#     = v_{term} t + \left(- v_{term}\right) \tau \left(1 - \left(1 - \frac{t}{\tau} + \frac{1}{2} \frac{t^2}{\tau^2} + \cdots \right)\right)
# $$
#
# $$
#     \tag{3}
#     = v_{term} t + \left(- v_{term}\right) \tau \left(\frac{t}{\tau} - \frac{1}{2} \frac{t^2}{\tau^2} + \cdots \right)
# $$
#
# $$
#     \tag{4}
#     \approx v_{term} t + \left(- v_{term}\right) t + v_{term} \frac{1}{2} \frac{t^2}{\tau}
# $$
#
# Once again, we assume that $\tau = \frac{m}{b}$ and $v_{ter} = \frac{mg}{b}$, which means we have:
# $$
#     \tag{5}
#     \approx \frac{mg}{b} t + \left(\frac{-mg}{b}\right) t + \frac{mg}{b} \frac{1}{2} t^2 \frac{m}{b}
# $$
#
# $$
#     \tag{6}
#     \approx \frac{mg}{b} \frac{1}{2} t^2 \frac{m}{b} \approx \frac{1}{2} g t^2
# $$

# %% [markdown]
# ### Exercise 4
#
# We are given:
# * $c = 0.20 \frac{\text{N}}{\left(\text{m/s}\right)^2}$
# * $m = 80 \text{kg}$
# * $t_0 = 0$
# * $v_0 = 20 \text{m/s}$
#
# We can use equation $\left(2.49\right)$:
# $$
#     v(t) = \frac{v_0}{1 + \frac{t}{\tau}}
# $$
#
# We can suppose that $\tau = \frac{m}{c v_0}$, which means we can say that:
# $$
#     v(t) = \frac{v_0}{1 + \frac{t c v_0}{m}}
# $$
#
# With a bit of algebraic manipulation, we can say that:
# $$
#     1 + \frac{t c v_0}{m} = \frac{v_0}{v}
# $$
#
# Which can be represented as:
# $$
#     t = \left(\frac{v_0}{v} - 1\right) \frac{m}{{c v_0}}
# $$
#
# To which we can find that:
# $$
#     t\left(15 \text{m/s}\right) = \left(\frac{20 \text{m/s}}{15 \text{m/s}} - 1\right) \frac{1}{0.20 \frac{\text{N}}{\left(\text{m/s}\right)^2} \cdot 20 \text{m/s}} \cdot 80 \text{kg} \approx 6.67 \text{s}
# $$
#
# $$
#     t\left(10 \text{m/s}\right) = \left(\frac{20 \text{m/s}}{10 \text{m/s}} - 1\right) \frac{1}{0.20 \frac{\text{N}}{\left(\text{m/s}\right)^2} \cdot 20 \text{m/s}} \cdot 80 \text{kg} = 20 \text{s}
# $$
#
# $$
#     t\left(5 \text{m/s}\right) = \left(\frac{20 \text{m/s}}{5 \text{m/s}} - 1\right) \frac{1}{0.20 \frac{\text{N}}{\left(\text{m/s}\right)^2} \cdot 20 \text{m/s}} \cdot 80 \text{kg} = 20 \text{s}
# $$

# %% [markdown]
# ### Exercise 5
#
# ---
#
# 5A.
#
# ---
# Clearly the only forces are the air resistance and gravity. This means that we have:
# ![diagram-20200131.svg](attachment:diagram-20200131.svg)
#
# The ball is really supposed to be centered around $x = 0$, however it would have made the drawing a bit difficult to see.
#
# * The two forces acting on the ball are $\mathbf{F}_G$ and $\mathbf{F}_R$.
# * We know that $\mathbf{F}_R = -f(v) \hat{\mathbf{v}}$
# * $\mathbf{v}_0 = \left( v_{x,0}, v_{y,0} \right)$
# * $\mathbf{r}(t_0) = \mathbf{r}_0 = \left(0, h\right)$
# * $\mathbf{F}_G = (0, -mg)$
# * $-f(v) = -D v^2$
# * $\mathbf{F}_R = -f(v) \hat{\mathbf{v}} = D v^2 \hat{\mathbf{v}}$
#
# From this, we can see that
# $$
#     \mathbf{F}_{net} = \mathbf{F}_R + \mathbf{F}_G =  D v^2 \hat{\mathbf{v}} + -mg \hat{\mathbf{e}_y}
# $$
# and that we can find the acceleration as:
# $$
#     \mathbf{a} = \frac{\mathbf{F}_{net}}{m} = \frac{1}{m} \left(D v^2 \hat{\mathbf{v}} + -mg \hat{\mathbf{e}_y}\right)
# $$
# which means we can calculate it, component by component, as:
# $$
#     \frac{1}{m} \left(\left(-D\|\mathbf{v}\| v_{0,x}, -D\|\mathbf{v}\| v_{0,y}\right) + \left(0, -mg\right)\right) = \left(-\frac{D}{m}\|\mathbf{v}\| v_{0,x}, -\frac{D}{m}\|\mathbf{v}\| v_{0,y} - mg\right) = -\frac{D}{m}\|\mathbf{v}\| \left(v_{0,x}, v_{0,y} - mg\right)
# $$
#
# We can alternatively format this by using the terminal velocity $\mathbf{v}_{term} = \sqrt{\frac{mg}{D}}$, which gives us:
# $$
#     \mathbf{a} = g\left(1 - \frac{v^2}{v_{term}^2}\right)
# $$
#
# ---
#
# 5B.
#
# ---
#
# To integrate this acceleration, we will use the terminal velocity version, as it is far easier to integrate. In this case, we must assume that $\mathbf{v}_0 = 0$, otherwise I have no idea how to solve that integral.
#
# $$
#     \tag{1}
#     \mathbf{\dot{v}} = g\left(1 - \frac{v^2}{v_{term}^2}\right)
# $$
#
# $$
#     \tag{2}
#     \frac{\mathbf{\dot{v}}}{\left(1 - \frac{v^2}{v_{term}^2}\right)} = g
# $$
#
# $$
#     \tag{3}
#     \int_{0}^{v(t)} \frac{dv}{\left(1 - \frac{v^2}{v_{term}^2}\right)} = \int_{t_0}^{t} g \ ds
# $$
#
# $$
#     \tag{4}
#     \frac{v_{ter}}{g} \cdot \text{arctanh}\left(\frac{v}{v_{ter}}\right) = t - t_0
# $$
#
# $$
#     \tag{5}
#     v = v_{ter} \cdot \text{tanh}\left(\frac{g(t - t_0)}{v_{ter}}\right)
# $$
#
# $$
#     \tag{6}
#     y = \frac{v_{ter}^2}{g} \cdot \ln\left(\text{cosh}\left(\frac{g(t - t_0)}{v_{ter}}\right)\right) + y_0
# $$
#
# The time it takes to hit the floor, is when $y = 0$, which occurs when:
# $$
#     0 = \frac{v_{ter}^2}{g} \cdot \ln\left(\text{cosh}\left(\frac{g(t - t_0)}{v_{ter}}\right)\right) + h
# $$
#
# $$
#     \tag{7}
#     \frac{-h}{\frac{v_{ter}^2}{g}} = \ln\left(\text{cosh}\left(\frac{g(t - t_0)}{v_{ter}}\right)\right)
# $$
#
# $$
#     \tag{8}
#     e^{\frac{-h g}{v_{ter}^2}} = \text{cosh}\left(\frac{g(t - t_0)}{v_{ter}}\right)
# $$
#
# $$
#     \tag{9}
#     \text{arccos}\left(e^{k}\right) = \frac{g(t - t_0)}{v_{ter}}, \qquad k = \frac{-h g}{v_{ter}^2}
# $$
#
# $$
#     \tag{10}
#     \frac{v_{ter}}{g} \cdot \text{arccos}\left(e^{k}\right) = t - t_0
# $$
#
# $$
#     \tag{11}
#     t =  \frac{v_{ter}}{g} \cdot \text{arccos}\left(e^{k}\right) + t_0
# $$
#
# We can calculate this value once we have a drag coefficient number.

# %%
# Problem 6
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib

# %%
# This code borrows heavily from the code provided by the professor, which can be located at the url:
# github.com/mhjensen/Physics321/blob/master/doc/src/motion/Programs/Hw3Exercise6v2.py

# Physical Constants
m = 0.2 # kg
g = 9.81 # m/s/s
h = 2 # m
v0_x = 10 # m/s
v0_y = 10 # m/s
D = 0.002 # m/s

# We now want to define how many measurements we make.
t_o = 0 # s
t_f = 25 # s

dt = 0.001 # s
N = int((t_f - t_o)/dt)

# Defining arrays
t = np.zeros(N, dtype=float) # One Dimensional Array
v = np.zeros((N, 2), dtype=float) # Two dimensional
a = np.zeros((N, 2), dtype=float) # Two dimensional
r = np.zeros((N, 2), dtype=float) # Two dimensional

# Defining a constant array for the Gravitational Force
F_G = np.array([0.00, (-m * g)])

# Assigning the initial conditions
t[0] = t_o
v[0] = np.array([v0_x, v0_y])
r[0] = np.array([0, h])

# Utilize Euler's Method
for i in range(N - 1):
    # The magnitude of the velocity vector.
    v_mag = np.sqrt(v[i] * v[i])
    
    # The Drag Force
    F_D = -D * v[i] * v_mag
    
    # The Net Force
    F_n = F_D + F_G
    
    # Calculating the acceleration using the net force
    a = F_n / m
    
    # Now to calculate using Euler's method
    v[i + 1] = v[i] + a*dt
    r[i + 1] = r[i] + v[i]*dt
    t[i + 1] = t[i] + dt

# This code is borrowed from the professor's code, which can be found at the link above.
(figure, axis) = plt.subplots(2, 1)
axis[0].plot(t, r[:, 1])
axis[0].set_xlim(0, t_f)
axis[0].set_ylabel('y')
axis[1].plot(t, v[:, 1])
axis[1].set_xlabel('time (s)')
axis[1].set_ylabel('v_y (m/s)')
figure.tight_layout()
plt.show()

# %% [markdown]
# ### An attempt at Exercise 7
#
# ---
#
# 7A.
#
# ---
#
# We are supposing that:
# $$
#     F_N = -k \left(\ R - y(t)\ \right) \ \hat{\mathbf{\jmath}}
# $$
#
# The free body diagram will appear as:
# ![diagram-20200203.svg](attachment:diagram-20200203.svg)
#
# Once again, the image should be centered around $x = 0$, but isn't for stylistic reasons.
#
# We know that the acceleration on the object can be found as such:
# $$
#     \mathbf{a} = \frac{\mathbf{F}_n}{m} = \mathbf{F}_G + \mathbf{F}_N + \mathbf{F}_D = -mg \ \hat{\mathbf{\jmath}} + -k \left(\ R - y(t)\ \right) \ \hat{\mathbf{\jmath}} + -f(v) \ \hat{\mathbf{v}} = \left(-mg - kR + ky\right) \ \hat{\mathbf{\jmath}} - D \| \mathbf{v} \| \ \mathbf{v}
# $$

# %%
# 7b
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib

# %%
# This will be using a lot of the same code as the problem previous to this (6)

# Constants
m = 0.2 # kg
g = 9.81 # m/s/s
h = 2 # m
v0_x = 10 # m/s
v0_y = 10 # m/s
D = 0.002 # m/s
k = 1000 # N/m
R = 0.1 # m

# Time constants
t_o = 0 # s
t_f = 150 # s

dt = 0.001 # s
N = int((t_f - t_o)/dt)

# Defining arrays
t = np.zeros(N, dtype=float) # One Dimensional Array
v = np.zeros((N, 2), dtype=float) # Two dimensional
a = np.zeros((N, 2), dtype=float) # Two dimensional
r = np.zeros((N, 2), dtype=float) # Two dimensional

# Defining a constant array for the Gravitational Force
F_G = np.array([0.00, (-m * g)])

# Defining the array for the Normal Force

# Assigning the initial conditions
t[0] = t_o
v[0] = np.array([v0_x, v0_y])
r[0] = np.array([0, h])

# Utilize Euler's Method
for i in range(N - 1):
    # The magnitude of the velocity vector.
    v_mag = np.sqrt(v[i] * v[i])
    
    # The Drag Force
    F_D = -D * v[i] * v_mag
    
    # The Normal force
    if r[i, 1] < R:
        F_N = k * (R - r[i]) * np.array([0, 1])
    else:
        F_N = 0
    
    # The Net Force
    F_n = F_D + F_G + F_N
    
    
    # Calculating the acceleration using the net force
    a = F_n / m
    
    # Now to calculate using Euler's method
    v[i + 1] = v[i] + a*dt
    r[i + 1] = r[i] + v[i]*dt
    t[i + 1] = t[i] + dt

# This code is borrowed from the professor's code, which can be found at the link above.
(figure, axis) = plt.subplots(2, 1)
axis[0].plot(t, r[:, 1])
axis[0].set_xlim(0, t_f)
axis[0].set_ylabel('y')
axis[1].plot(t, v[:, 1])
axis[1].set_xlabel('time (s)')
axis[1].set_ylabel('v_y (m/s)')
figure.tight_layout()
plt.show()
