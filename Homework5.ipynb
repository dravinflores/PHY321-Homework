# %% [markdown]
# # PHY 321 Homework 5
# Dravin Flores
#
# ---
#
# ## Exercise 1
#
# ---
#
# 1A.
#
# ---
#
# * This force is indeed a conservative force, as it only depends upon the position of an electron. This means that this force will lead to the conservation of energy.
# * This also means that we can derive a formula for the kinetic energy and potential energy using some initial energy value.
# * Lastly, this means that the *Work-Energy Theorem* applies to this particular force.
#
#
# ---
#
# 1B.
#
# ---
#
# * The work energy theorem can be stated as
#
# $$
#     \Delta K = K_2 - K_1 = \int_{1}^{2} \mathbf{F} \cdot d\mathbf{R} = W(1 \to 2)
# $$
#
# * We can use this theorem by doing the following:
#
# $$
#     \tag{1}
#     \frac{1}{2} m \ v^2 (x) - \frac{1}{2} m \ v_{0}^2 = \int_{1}^{2} \mathbf{F} \cdot d\mathbf{R}
# $$
#
# $$
#     \tag{2}
#     \frac{1}{2} m \ v^2 (x) = \frac{1}{2} m \ v_{0}^2 + \int_{1}^{2} F_x \cdot dx
# $$
#
# $$
#     \tag{3}
#     \frac{1}{2} m \ v^2 (x) = \frac{1}{2} m \ v_{0}^2 + \int_{1}^{2} -F_0 \sin{\left(\frac{2 \pi}{b} x\right)} dx
# $$
#
# $$
#     \tag{4}
#     \frac{1}{2} m \ v^2 (x) = \frac{1}{2} m \ v_{0}^2 + \left( \frac{F_0 b}{2 \pi} \right) \cos{\left(\frac{2 \pi}{b} x\right) \Big|_{1}^{2}}
# $$
#
# $$
#     \tag{5}
#     \frac{1}{2} m \ v^2 (x) = \frac{1}{2} m \ v_{0}^2 + \left( \frac{F_0 b}{2 \pi} \right) \left( \cos{\left(\frac{2 \pi}{b} x\right)} - \cos{\left(\frac{2 \pi}{b} x_{0}\right)} \right)
# $$
#
# $$
#     \tag{6}
#     v^2 (x) = v_{0}^2 + \frac{2}{m} \left( \frac{F_0 b}{2 \pi} \right) \left( \cos{\left(\frac{2 \pi}{b} x\right)} - \cos{\left(\frac{2 \pi}{b} x_{0}\right)} \right)
# $$
#
# $$
#     \tag{7}
#     v(x) = \pm \sqrt{v_{0}^2 + \frac{2}{m} \left( \frac{F_0 b}{2 \pi} \right) \left( \cos{\left(\frac{2 \pi}{b} x\right)} - \cos{\left(\frac{2 \pi}{b} x_{0}\right)} \right)}
# $$
#
# ---
#
# 3C.
#
# ---
#
# * We know that
#
# $$
#     \mathbf{F} = - \nabla V(x)
# $$
#
# * Which means
#
# $$
#     - \int F dx = V(x)
# $$
#
# * And
#
# $$
#     \int F_0 \sin{ \left( \frac{2 \pi}{b} x \right) } dx
# $$

# %% [markdown]
# ## Exercise 2
#
# ---
#
# 2A.
#
# ---
#
# * We are given an external force $F^{\ \text{ext}}$, which means that
#
# $$
#     \sum_{i} F_{i} = F^{\ \text{ext}}
# $$

# %% [markdown]
# ## Exercise 3
#
# ---
#
# 3A.
#
# ---
#
# #### 3.13
# * The velocity for 3.11(b) was
#
# $$
#     v(t) = v_{ex} \ln{\left(\frac{m_0}{m}\right)} - gt
# $$
#
# * The integral of this is:
#
# $$
#     \int_{0}^{y} v_{ex} \ln{\left(\frac{m_0}{m}\right)} - gt \ dt = v_{ex} \int_{0}^{y} \ln{\left(\frac{m_0}{m}\right)} \ dt - \int_{0}^{y} - gt \ dt = v_{ex} \int_{0}^{y} \ln{\left(\frac{m_0}{m_0 - kt'}\right)} \ dt - g \int_{0}^{t} t dt
# $$
#
# $$
#     \Rightarrow \qquad y(t) = v_{ex} t - \frac{gt^2}{2} - \frac{m v_{ex}}{k} \ln{\left(\frac{m_0}{m}\right)}
# $$
#
# * We are given the numbers: $m_0 = 2 \times 10^{6}$ kg, $m = 1 \times 10^{6}$ kg, $v_{ex} = 3000$ m/s, and $v_0 = 0$ m/s.
#
# * This means that we have:
#
# $$
#     y(2) = 3000 \cdot 2 - \frac{1 \times 10^{6} \cdot 3000}{\frac{1 \times 10^{6} - 2 \times 10^{6}}{2}} \ln{\left(\frac{2 \times 10^{6}}{1 \times 10^{6}}\right)} \approx 10159 \text{m}
# $$

# %% [markdown]
# ## Exercise 4
#
# ---
#
# 4A.
#
# ---
#
# * In 3.3 of Taylor, we are given the following formulas:
#
# $$
#     \tag{1}
#     \mathbf{R} = \frac{1}{M} \sum_{\alpha=1}^{N} m_{\alpha} \mathbf{r}_{\alpha}
# $$
#
# $$
#     \tag{2}
#     M = \sum_{\alpha=1}^{N} m_{\alpha}
# $$
#
# * We are also given two bodies, with masses $M_1$ and $M_2$ and center of masses $\mathbf{R}_1$ and $\mathbf{R}_2$.
#
# * We will create an inertial frame of reference with the common origin $O$, so that we can find the center of mass for this system.
#
# * We should note that:
#
# $$
#     M_1 = \sum_{\alpha=1}^{N} m_{1, \alpha}, \quad M_2 = \sum_{\alpha=1}^{N} m_{2, \alpha}
# $$
#
# * We should also note that
#
# $$
#     \mathbf{R}_1 = \frac{1}{M_1} \sum_{\alpha=1}^{N} m_{1, \alpha} \ \mathbf{r}_{1, \alpha}, \quad \mathbf{R}_2 = \frac{1}{M_2} \sum_{\alpha=1}^{N} m_{2, \alpha} \ \mathbf{r}_{2, \alpha}
# $$
#
# * We know that the net mass can be given using formula (1) as:
#
# $$
#     M' = \sum_{\alpha=1} M_{\alpha} = M_1 + M_2 = \sum_{\alpha=1}^{N} m_{1, \alpha} + \sum_{\alpha=1}^{N} m_{2, \alpha} = \sum_{\alpha=1}^{N} m_{1, \alpha} + m_{2, \alpha}
# $$
#
# * We also know that we can find the center of mass using formula (2) as:
#
# $$
#     \mathbf{R}' = \frac{1}{M'} \sum_{\alpha=1}^{N} M_{\alpha} \mathbf{R}_{\alpha} = \frac{1}{M_1} \sum_{\alpha=1}^{N} m_{1, \alpha} \ \mathbf{r}_{1, \alpha} + \frac{1}{M_2} \sum_{\alpha=1}^{N} m_{2, \alpha} \ \mathbf{r}_{2, \alpha} = \frac{1}{M'} \left( M_{1} \mathbf{R}_{1} + M_{2} \mathbf{R}_{2} \right) = \frac{M_{1} \mathbf{R}_{1} + M_{2} \mathbf{R}_{2}}{M_1 + M_2}
# $$
#
# * This result follows from the two equations above, as well as from the idea layed out in Chapter 3 of Taylor, that a center of mass can be treated as a point particle with a particular mass $M$ and a position $\mathbf{R}$ as the net force of this particle can be found as
#
# $$
#     \mathbf{F}^{\text{ext}} = M \ddot{\mathbf{R}}
# $$
#
# * The equation above helps us to understand why our result is valid. Thus, we can treat the center of mass as a good representation of the position of the system, the sum of the mass as a good representation of the mass of the system, and package everything into a single particle, which then allows us to talk about that system's motion simply.

# %% [markdown]
# ## Exercise 5
#
# ---
#
# 5A.
#
# ---
#
# * We were given the force as
#
# $$
#     m \frac{d^2 x}{dt^2} + kx = 0
# $$
#
# * We could use the general form
#
# $$
#     m \frac{d^2 x}{dt^2} + b \frac{dx}{dt} + kx = 0
# $$
#
# * Thus, we can see that $b = 0$.
# * This force that is being modeled is a conservative force as it only directly depends upon the position. Therefore, this force conserves energy as the work done by the net force is path independant.
#
# ---
#
# 5B.
#
# ---
#
# $$
#     \tag{1}
#     m \frac{d^2 x}{dt^2} + b \frac{dx}{dt} + kx = 0
# $$
#
# $$
#     \tag{2}
#     \omega_{0}^{2} = \frac{k}{m}
# $$
#
# $$
#     \tag{3}
#     \frac{d^2 x}{dt^2} + \frac{b}{m} \frac{dx}{dt} + \frac{k}{m} x = 0 \qquad \Rightarrow \qquad \frac{d^2 x}{dt^2} + \frac{b}{m} \frac{dx}{dt} + \omega_{0}^{2} x = 0
# $$
#
# * With $b = 0$ and a little algebraic manipulation, we can say that
#
# $$
#     \frac{d^2 x}{dt^2} = -\omega_{0}^{2} x
# $$
#
# * As for the dimension of $\omega_{0}$, we have
#
# $$
#     \left[\omega_{0}\right] = \left[\ \sqrt{\frac{k}{m}} \ \right] = \sqrt{\frac{\text{N/m}}{\text{kg}}} = \sqrt{\frac{1}{\text{s}^2}} = \frac{1}{\text{s}}
# $$
#
# ---
#
# 5C.
#
# ---
#
# $$
#     \tag{1}
#     \tau = t \omega_0 \qquad \Rightarrow \qquad d \tau = \omega_{0} dt, \qquad d \tau^2 = \omega_{0}^{2} dt^2
# $$
#
# $$
#     \tag{2}
#     \frac{d^2 x}{dt^2} = -\omega_{0}^{2} x \qquad \Rightarrow \qquad \frac{d^2 x}{d\tau^2} \omega_{0}^{2} =  -\omega_{0}^{2} x
# $$
#
# $$
#     \tag{3}
#     \frac{d^2 x}{d\tau^2} = -x
# $$
#
# $$
#     \tag{4}
#     \frac{d}{d\tau} \left( \frac{dx}{d\tau} \right) = -x \qquad \Rightarrow \qquad \frac{dv}{d\tau} = -x
# $$
#
# $$
#     \tag{5}
#     \frac{dx}{d\tau} = v
# $$
#
# $$
#     \left[ \frac{dx}{d\tau} \right] = \text{m}, \qquad \left[ \frac{d^2 x}{d\tau^2} \right] = \text{m}
# $$

# %% [markdown]
# ## Exercise 6
#
# ---
#
# 6A.
#
# ---
#
# * We are given the function
#
# $$
#     \frac{d^2 x}{dt^2} = -\omega_{0}^{2} x
# $$
#
# * We are also given the initial conditions:
#
# $$
#     x(0) = 1, \quad x'(0) = 0
# $$
#
# * We can find the solution to this differential equation using the initial conditions as:
#
# $$
#     x(t) = cos(\omega t)
# $$

# %%
# Exercise 6

import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
import math
# %matplotlib inline

def calculate_analytic(tf=10.0, ti=0.0, dt=0.001, omega=1, r0=0):
    n = math.ceil( (tf - ti) / dt)
    t = np.zeros(n)
    x = np.zeros(n)
    v = np.zeros(n)
    x[0] = r0
    
    for i in range(n - 1):
        t[i+1] = t[i] + dt
        x[i+1] = math.cos(omega * t[i])
        
    return (t, x)
        

def get_acceleration(g=0, v=0, x=0):
    # Here we expect gamma to be zero. 
    return -2*g*v - x

def calculate_euler(tf=10.0, ti=0.0, dt=0.001, r0=0, v0=0):
    # We need to know how many intervals to calculate.
    n = math.ceil( (tf - ti) / dt)

    # These are the arrays that will store our data.
    t = np.zeros(n)
    r = np.zeros(n)
    v = np.zeros(n)

    # Setting up the initial position and velocity vectors.
    r[0] = r0
    v[0] = v0

    for i in range(n - 1):
        a = get_acceleration(0, 0, r[i])
        
        v[i+1] = v[i] + a*dt
        r[i+1] = r[i] + v[i]*dt
        t[i+1] = t[i] + dt
        
    return (t, r, v)


def calculate_euler_cromer(tf=10.0, ti=0.0, dt=0.001, r0=0, v0=0):
    # We need to know how many intervals to calculate.
    n = math.ceil( (tf - ti) / dt)

    # These are the arrays that will store our data.
    t = np.zeros(n)
    r = np.zeros(n)
    v = np.zeros(n)

    # Setting up the initial position and velocity vectors.
    r[0] = r0
    v[0] = v0
    
    for i in range(n - 1):
        a = get_acceleration(0, 0, r[i])
        
        v[i+1] = v[i] + a*dt
        r[i+1] = r[i] + v[i+1]*dt
        t[i+1] = t[i] + dt
        
    return (t, r, v)


def calculate_velocity_verlet(tf=10.0, ti=0.0, dt=0.001, r0=0, v0=0):
    # We need to know how many intervals to calculate.
    n = math.ceil( (tf - ti) / dt)

    # These are the arrays that will store our data.
    t = np.zeros(n)
    r = np.zeros(n)
    v = np.zeros(n)

    # Setting up the initial position and velocity vectors.
    r[0] = r0
    v[0] = v0
    
    for i in range(n - 1):
        a = get_acceleration(0, 0, r[i])
        
        r[i+1] = r[i] + v[i]*dt + 0.5*a * (dt ** 2)
        ap = get_acceleration(0, 0, r[i+1])
        
        v[i+1] = v[i] + 0.5*(a + ap)*dt
        t[i+1] = t[i] + dt
        
    return (t, r, v)


# Intial Conditions
r_0 = 1
v_0 = 0

# calculate_velocity_verlet(1, 0.001, 10, 0, r0, v0)

# (ta, ra, va) = calculate_euler(r0=r_0)
(ta, ra) = calculate_analytic(omega=1, r0=r_0)
(tb, rb, vb) = calculate_euler_cromer(r0=r_0)
(tc, rc, vc) = calculate_velocity_verlet(r0=r_0)

# Plot the data
# (figure, axis) = plt.subplots()
# axis.set_xlabel('x (m)')
# axis.set_ylabel('y (m)')
# axis.plot(ra[:, 0], ra[:, 1])
# figure.tight_layout()


plt.subplot(1, 3, 1)
plt.plot(ta, ra)
axis.set_xlabel('x (m)')
axis.set_ylabel('y (m)')
plt.title("Analytic")
# plt.tight_layout()

plt.subplot(1, 3, 2)
plt.plot(tb, rb)
axis.set_xlabel('x (m)')
axis.set_ylabel('y (m)')
plt.title("Euler Cromer's Method")
# plt.tight_layout()

plt.subplot(1, 3, 3)
plt.plot(tc, rc)
axis.set_xlabel('x (m)')
axis.set_ylabel('y (m)')
plt.title("Velocity Verlet's Method")
# plt.tight_layout()

plt.show()

# %% [markdown]
# ## Exercise 7 cont.
#
# * We can see that our numerical result is the same as our analytical result, as our function was simplified due to the lack of a dependence upon $\gamma$ anywhere in our problem. This was a nice result, because this means that any of our numerical results conserve energy, as we can guarantee that our numerical result conserves energy.
# * We can guarantee that our analytical result conserves energy as our forces are solely position dependent.

# %% [markdown]
# ## Exercise '8'
#
# * We were given the equation:
#
# $$
#     \tag{1}
#     m \frac{d^2 x(t)}{dt^2} + \beta \frac{dx}{dt} + kx = m a(t) + \beta v(t) + k x(t) = 0
# $$
#
# $$
#     \tag{2}
#     \frac{d^2 x(t)}{dt^2} + \frac{\beta}{m} \frac{dx}{dt} + \frac{k}{m} x = 0
# $$
#
# $$
#     \tag{3}
#     \tau = t \ \omega_0, \quad \omega_{0}^{2} = \frac{k}{m}, \quad d\tau = \omega_0 dt
# $$
#
# $$
#     \tag{4}
#     \frac{d^2 x(t)}{d\tau^2} \omega_{0}^{2} + \frac{\beta \omega_{0}}{m} \frac{dx}{d\tau} + \omega_{0}^{2} x = 0
# $$
#
# $$
#     \tag{5}
#     \frac{d^2 x(t)}{d\tau^2} + \frac{\beta}{m \omega_{0}} \frac{dx}{d\tau} + x = 0
# $$
#
# $$
#     \tag{6}
#     \frac{d^2 x(t)}{d\tau^2} = \frac{d}{d\tau} \left( \frac{dx}{d\tau} \right) = \frac{dv}{d\tau} = a
# $$
#
# $$
#     \tag{7}
#     \left( \frac{dx}{d\tau} \right) = v
# $$
#
# $$
#     \tag{8}
#     a + \frac{\beta}{m \omega_{0}} v + x = 0
# $$
#
# $$
#     \tag{9}
#     \gamma = \frac{\beta}{2m}
# $$
#
# $$
#     \tag{10}
#     a + 2 \gamma \frac{1}{\omega_{0}} v + x = 0
# $$
#
# $$
#     \tag{11}
#     a = - 2 \gamma \frac{1}{\omega_{0}} v - x
# $$
#
# $$
#     \tag{12*}
#     \gamma = \frac{\beta}{2m \omega_0}
# $$
#
# $$
#     \tag{13*}
#     a = - 2 v \gamma - x
# $$
#
# * It should be noted that (12*) is a modification of the definition provided, just to get rid of the extra factor of $\frac{1}{\omega_0}$.
# * The dimensionality of our velocity function should be such:
#
# $$
#     \left[ \frac{dx}{d\tau} \right] = \text{length}
# $$
#
# * The dimensionality of $\gamma$ should be such:
#
# $$
#     \left[ \gamma \right] = \frac{\text{kg/s}}{\text{kg}} = \frac{1}{\text{s}}
# $$

# %%
# Code for Exercise 8

import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
import math
# %matplotlib inline


def get_acceleration(g=0, v=0, x=0):
    # Here we expect gamma to not be zero. 
    return -2*g*v - x

def calculate_euler(tf=10.0, ti=0.0, dt=0.001, r0=0, v0=0, gamma=1):
    # We need to know how many intervals to calculate.
    n = math.ceil( (tf - ti) / dt)

    # These are the arrays that will store our data.
    t = np.zeros(n)
    r = np.zeros(n)
    v = np.zeros(n)

    # Setting up the initial position and velocity vectors.
    r[0] = r0
    v[0] = v0

    for i in range(n - 1):
        a = get_acceleration(gamma, v[i], r[i])
        
        v[i+1] = v[i] + a*dt
        r[i+1] = r[i] + v[i]*dt
        t[i+1] = t[i] + dt
        
    return (t, r, v)


def calculate_euler_cromer(tf=10.0, ti=0.0, dt=0.001, r0=0, v0=0, gamma=1):
    # We need to know how many intervals to calculate.
    n = math.ceil( (tf - ti) / dt)

    # These are the arrays that will store our data.
    t = np.zeros(n)
    r = np.zeros(n)
    v = np.zeros(n)

    # Setting up the initial position and velocity vectors.
    r[0] = r0
    v[0] = v0
    
    for i in range(n - 1):
        a = get_acceleration(gamma, v[i], r[i])
        
        v[i+1] = v[i] + a*dt
        r[i+1] = r[i] + v[i+1]*dt
        t[i+1] = t[i] + dt
        
    return (t, r, v)


def calculate_velocity_verlet(tf=10.0, ti=0.0, dt=0.001, r0=0, v0=0, gamma=1):
    # We need to know how many intervals to calculate.
    n = math.ceil( (tf - ti) / dt)

    # These are the arrays that will store our data.
    t = np.zeros(n)
    r = np.zeros(n)
    v = np.zeros(n)

    # Setting up the initial position and velocity vectors.
    r[0] = r0
    v[0] = v0
    
    for i in range(n - 1):
        a = get_acceleration(gamma, v[i], r[i])
        
        r[i+1] = r[i] + v[i]*dt + 0.5*a * (dt ** 2)
        ap = get_acceleration(0, 0, r[i+1])
        
        v[i+1] = v[i] + 0.5*(a + ap)*dt
        t[i+1] = t[i] + dt
        
    return (t, r, v)


# Intial Conditions
r_0 = 1
v_0 = 0


(ta, ra, va) = calculate_euler(tf=25, r0=r_0, v0=v_0, gamma=0.5)
(tb, rb, vb) = calculate_euler_cromer(tf=25, r0=r_0, v0=v_0, gamma=0.5)
(tc, rc, vc) = calculate_velocity_verlet(tf=25, r0=r_0, v0=v_0, gamma=0.5)

def plot_stuff(t_a, r_a, t_b, r_b, t_c, r_c):
    plt.subplot(1, 3, 1)
    plt.plot(ta, ra)
    axis.set_xlabel('x (m)')
    axis.set_ylabel('y (m)')
    plt.title("Euler's Method")
    # figure.tight_layout()

    plt.subplot(1, 3, 2)
    plt.plot(tb, rb)
    axis.set_xlabel('x (m)')
    axis.set_ylabel('y (m)')
    plt.title("Euler Cromer's Method")
    # figure.tight_layout()

    plt.subplot(1, 3, 3)
    plt.plot(tc, rc)
    axis.set_xlabel('x (m)')
    axis.set_ylabel('y (m)')
    plt.title("Velocity Verlet's Method")
    # figure.tight_layout()

    plt.show()
    
plot_stuff(ta, ra, tb, rb, tc, rc)

# %%
(ta, ra, va) = calculate_euler(tf=25, r0=r_0, v0=v_0, gamma=1)
(tb, rb, vb) = calculate_euler_cromer(tf=25, r0=r_0, v0=v_0, gamma=1)
(tc, rc, vc) = calculate_velocity_verlet(tf=25, r0=r_0, v0=v_0, gamma=1)
plot_stuff(ta, ra, tb, rb, tc, rc)

# %%
(ta, ra, va) = calculate_euler(tf=25, r0=r_0, v0=v_0, gamma=5)
(tb, rb, vb) = calculate_euler_cromer(tf=25, r0=r_0, v0=v_0, gamma=5)
(tc, rc, vc) = calculate_velocity_verlet(tf=25, r0=r_0, v0=v_0, gamma=5)

plot_stuff(ta, ra, tb, rb, tc, rc)

# %% [markdown]
# ## Exercise 8 cont.
#
# * We can see that in underdamping, the system has oscillatory motion, however the initial amplitude is quickly squished. Our time interval might be too short to really see the full motion, however we can observe that the oscillatory motion decays (i.e. it eventually comes to a stop).
# * In critical damping, the system quickly comes to a stop. It should be noted that the velocity-verlet method might have some bug in the Python code, as the graph does not appear as expected.
# * In the overdamping example, the system does not quickly come to a stop. It is clear that it takes a bit more time.

# %% [markdown]
# ---
#
# # Notes
#
# ---
#
# * If the Python code throws errors, then something went wrong. I've found that running them sequentially (i.e. Exercise 6 code, then Exercise 8 code) seems to remove errors. However this might not be truly portable.
